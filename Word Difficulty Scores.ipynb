# %%
import os
import spacy
from textstat.textstat import textstatistics,legacy_round
import pandas as pd

# %%
# Splits the text into sentences, using 
# Spacy's sentence segmentation which can 
# be found at https://spacy.io/usage/spacy-101
def break_sentences(text):
    nlp = spacy.load('en_core_web_sm')
    doc = nlp(text)
    return list(doc.sents)

# Returns Number of Words in the text
def word_count(text):
    sentences = break_sentences(text)
    words = 0
    for sentence in sentences:
        words += len([token for token in sentence])
    return words

# Returns the number of sentences in the text
def sentence_count(text):
    sentences = break_sentences(text)
    return len(sentences)

# Returns average sentence length
def avg_sentence_length(text):
    words = word_count(text)
    sentences = sentence_count(text)
    average_sentence_length = float(words / sentences)
    return average_sentence_length


def syllables_count(word):
    return textstatistics().syllable_count(word)


def avg_syllables_per_word(text):
    syllable = syllables_count(text)
    words = word_count(text)
    ASPW = float(syllable) / float(words)
    return legacy_round(ASPW, 1)

# Return total Difficult Words in a text
def difficult_words(text):

    nlp = spacy.load('en_core_web_sm')
    doc = nlp(text)
    # Find all words in the text
    words = []
    sentences = break_sentences(text)
    for sentence in sentences:
        words += [str(token) for token in sentence]

    # difficult words are those with syllables >= 2
    # easy_word_set is provide by Textstat as 
    # a list of common words
    diff_words_set = set()

    for word in words:
        syllable_count = syllables_count(word)
        if word not in nlp.Defaults.stop_words and syllable_count >= 2:
            diff_words_set.add(word)

    return len(diff_words_set)


def poly_syllable_count(text):
    count = 0
    words = []
    sentences = break_sentences(text)
    for sentence in sentences:
        words += [token for token in sentence]


    for word in words:
        syllable_count = syllables_count(word)
        if syllable_count >= 3:
            count += 1
    return count


def flesch_reading_ease(text):
    """
        Implements Flesch Formula:%%!
        Reading Ease score = 206.835 - (1.015 × ASL) - (84.6 × ASW)
        Here,
        ASL = average sentence length (number of words 
                divided by number of sentences)
        ASW = average word length in syllables (number of syllables 
            divided by number of words)
    """
    FRE = 206.835 - float(1.015 * avg_sentence_length(text)) -\
        float(84.6 * avg_syllables_per_word(text))
    return legacy_round(FRE, 2)


def gunning_fog(text):
    per_diff_words = (difficult_words(text) / word_count(text) * 100) + 5
    grade = 0.4 * (avg_sentence_length(text) + per_diff_words)
    return grade


def smog_index(text):
    """
        Implements SMOG Formula / Grading
        SMOG grading = 3 + ?polysyllable count.
        Here, 
        polysyllable count = number of words of more
        than two syllables in a sample of 30 sentences.
    """

    if sentence_count(text) >= 3:
        poly_syllab = poly_syllable_count(text)
        SMOG = (1.043 * (30*(poly_syllab / sentence_count(text)))**0.5) \
                + 3.1291
        return legacy_round(SMOG, 1)
    else:
        return 0


def dale_chall_readability_score(text):
    """
        Implements Dale Challe Formula:%%!
        Raw score = 0.1579*(PDW) + 0.0496*(ASL) + 3.6365
        Here,
            PDW = Percentage of difficult words.
            ASL = Average sentence length
    """
    words = word_count(text)
    # Number of words not termed as difficult words
    difficult_words_count = difficult_words(text)
    count = words - difficult_words_count
    if words > 0:

        # Percentage of words not on difficult word list

        per = float(count) / float(words) * 100
        
# diff_words stores percentage of difficult words
    diff_words = 100 - per

    raw_score = (0.1579 * diff_words) + \
        (0.0496 * avg_sentence_length(text))

# If Percentage of Difficult Words is greater than 5 %, then;
# Adjusted Score = Raw Score + 3.6365,
    # otherwise Adjusted Score = Raw Score
    if diff_words > 5: 

        raw_score += 3.6365
        
    return legacy_round(raw_score, 2)

# %%
path = "../sentences-to-annotate/"
dir_list = os.listdir(path)

# %%
word_difficulty = {}
for file in dir_list:
    dataframe1 = pd.read_excel(path+file)
    print(path+file)
    essay = ""
    print(dataframe1["sentence"])
    for sentence in dataframe1["sentence"]:
        if type(sentence) == str:
            essay = essay + sentence
    if file not in word_difficulty.keys():
        word_difficulty[file] = {}
#     word_difficulty[file]["text_standard"] =  textstat.text_standard(essay)
    essay = essay.title()
    word_difficulty[file]["essay"] = essay
    word_difficulty[file]["flesch_reading_ease"] = flesch_reading_ease(essay)
    word_difficulty[file]["difficult words"] = difficult_words(essay)
    word_difficulty[file]["dale_chall_readability_score"] = dale_chall_readability_score(essay)
# Out:
# ../sentences-to-annotate/1000617.xlsx
# 0     Nowadays everything has to be nice, new, good ...
# 1     These are important qualities which have to fu...
# 2     So it is ok that many advertisements make prod...
# 3     Well in my opinion it's absolutly ok but maybe...
# 4     At the moment I'm studying mediadesign in Berlin.
# 5     For that reason I have to learn and develop wa...
# 6     Of course perhaps it is a little bit wrong but...
# 7     I had a professor who told us that he had to d...
# 8     So he solved the problem by taking a piece of ...
# 9     Equally important is the fact that people only...
# 10      So how would you present maybe diet - products?
# 11    Would you show a fat lady with the nice and ne...
# 12             I think not a really difficult question.
# 13    Of course I can understand the people who say ...
# 14    But in this case I think that this is their fa...
# 15    You can't say that advertising agencies should...
# 16    In my opinion every business have to do their ...
# 17    All in all I have to say that advertising is g...
# 18                            This is a growing part of
# Name: sentence, dtype: object
# ../sentences-to-annotate/1302106.xlsx
# 0     I agree that  most advertisements really make ...
# 1     Businessmen do not care about other people' ri...
# 2     Athough some products which are made by famous...
# 3                                                   NaN
# 4     I still remember when I was a child, I saw a v...
# 5     I disagreed with them and finally bought the t...
# 6     After I got home, I was so exciting and opend ...
# 7          It was the worst toy I had ever seen before.
# 8                                        I felt so sad.
# 9                         I was crying for whole night.
# 10                                                  NaN
# 11    After that time, I do not believe those beauti...
# 12    I think it realy dishonst for people who bough...
# 13    The businessmen make the advertisements which ...
# 14    It is fine for me if there is only a little di...
# 15    But sadlly most of advertisements for the prod...
# 16    I realy hate those advertisements, but that is...
# 17    I think in the furture there will still be a l...
# Name: sentence, dtype: object
# ../sentences-to-annotate/1028214.xlsx
# 0     We are facing thousands of advertisements in o...
# 1     They are easy to say "nothing is better than t...
# 2                            However are they all true?
# 3                                     I don't think so.
# 4     They do 'over-advertising' the product than th...
# 5                                                   NaN
# 6     First, i declare most advertisements make good...
# 7     Last year, i had really long black hair but my...
# 8     At that time, a ran into some advertisment wit...
# 9     What i felt that time was, if i use that produ...
# 10    I used it for a long time but i couldn't have ...
# 11    First i was depressed, but than i began to thi...
# 12                                  'Over-advertising'.
# 13                                                  NaN
# 14    Moreover, in my opinion there is resonable rea...
# 15    From my experience that i mentioned above,  i ...
# 16    Why couldn't be just honest so that no one wou...
# 17                                Then, i got the idea.
# 18    There's hundreds of different shampoo in the m...
# 19    To take attention from people, they have to be...
# 20                                                  NaN
# 21                                             in short
# Name: sentence, dtype: object
# ../sentences-to-annotate/98792.xlsx
# 0     I strongly disagree with this statement which ...
# 1     There are some some reasons so that i disagree...
# 2     The main reason is, it is law that,you have to...
# 3                                                   NaN
# 4     As I talked about the law, it is the responsib...
# 5     If they break the law and not give the right i...
# 6     If it proof in the court, they lose their lice...
# 7     Another reason is that they lose the people's ...
# 8     So they never cheat the people whether it is a...
# 9     By advertise wrong information, they make a bi...
# 10                                                  NaN
# 11    Taking a good example of any electronics compa...
# 12      Suppose company advertise the computer systems.
# 13    If they don't mention the limitations with its...
# 14    Sometimes some companies do these kinds of mis...
# 15    So every company advertise their product witho...
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# 30                                                  NaN
# 31                                                  NaN
# Name: sentence, dtype: object
# ../sentences-to-annotate/1014926.xlsx
# 0     There are alot of way to advertisment the prod...
# 1     The most imporatant qusation is it is really t...
# 2     I think some ads show the product for people o...
# 3     In the most ads the dont mention the bad thing...
# 4     Some of the statistic said that in 2002 there ...
# 5     Some of the ads use some lies so they can sell...
# 6     Also we dont have to forget the people and how...
# 7     So some times they used some tricks so they ca...
# 8     The people who watch the TV alot some times th...
# 9     They started to ordered after the ad dirictlly...
# 10    Indeed some of the products seem much beteer t...
# Name: sentence, dtype: object
# ../sentences-to-annotate/636999.xlsx
# 0    All days we take car to go at work, take train...
# 1    On the train we can read uppon the window that...
# 2    This are the advertisements that daily we can ...
# 3    Just when we are child, parents show what is d...
# 4    During the grow each child decide what is righ...
# 5    Sometimes an advertisement could seem very ecc...
# 6    I think that it is impossible know whether a p...
# 7    Finally I definitely disagree the statement be...
# Name: sentence, dtype: object
# ../sentences-to-annotate/293268.xlsx
# 0     Everyone knows that adverts are made on purpos...
# 1     sometimes it happens that you watch an adverti...
# 2     Basically  they show you many evident qualitie...
# 3     This point can easily be explained mentioning ...
# 4     In fact, what products really need for being s...
# 5     it means that the value of an object is determ...
# 6     Provided that behind every advertisement there...
# 7     For "objective prospective" i mean that people...
# 8     messages i am  talking about are generally use...
# 9     So ,according to what i have just analysed, i ...
# 10    In my opinion advert- mechanism is a clear exa...
# 11    I reckon that this situation is very dangerous...
# Name: sentence, dtype: object
# ../sentences-to-annotate/115179.xlsx
# 0     I do agree that advertisements make products s...
# 1     The main focus of advertisements is to make it...
# 2     A good example of these reasons are: diet pill...
# 3     They make ordinarily difficult goals to obtain...
# 4     First of all, they target the one thing humans...
# 5     Todays men and women understand the importance...
# 6     Healthy bodies and weight loss come from: heal...
# 7     Diet pills advertisements make it seem as if y...
# 8     Still people buy these products because they w...
# 9     To understand how this operates we must look f...
# 10    First of all , the image of expressing the eas...
# 11    This isn't a new practice every product will s...
# Name: sentence, dtype: object
# ../sentences-to-annotate/849976.xlsx
# 0     I srongly agree with the statement that  most ...
# 1     Firstly take the example of Shampoos, now a da...
# 2     In the market you can find a large number of s...
# 3     In that case the advertisements will  gave you...
# 4     A well directed advertisement in which a girl ...
# 5     Only after using it you will came across the a...
# 6     The advertisements main aim is to attract more...
# 7          Its the case  in most type of cosmetics too.
# 8     Second take the example of  Yogurts, or any ot...
# 9       They are not  what they look in advertisements.
# 10    Finally i  believe that if you take the exampl...
# 11    To sum up I can say that in most of the cases ...
# Name: sentence, dtype: object
# ../sentences-to-annotate/1020096.xlsx
# 0     From the this question i would say, i strongly...
# 1           theseday we can see advertising everywhere.
# 2     so we can have effect by advertising but most ...
# 3     most products seem really nice in the advertis...
# 4                                         but It's not.
# 5     because advertiser want to sell thier products...
# 6           for example, fewdays ago i bought bulejean.
# 7     i saw advertising from TV and jeans color is r...
# 8                    so i bought jean use the internet.
# 9            but when i got a jean, color is different.
# 10                                      they lie to me.
# 11    second, advertiser get a money from the produc...
# 12    so advertiser make famous advertisements in ad...
# 13    and If product sell very much, his advertising...
# 14    finally, from the this reason first, advertise...
# 15                                                   so
# Name: sentence, dtype: object
# ../sentences-to-annotate/83310.xlsx
# 0    In my opinion a lot of advertisement increase ...
# 1    Such as shoes, there are some brand of shoes t...
# 2    The television play an important role about th...
# 3    A lot of people watch the TV and generally fol...
# 4    Sometimes if I am skilled about the thing (suc...
# 5    When a brand spent some money for make it's ad...
# 6    The charateristics of a product can be the sam...
# 7    Many times the person who buy an advertise obj...
# 8    The advertise can be not exhaustive and can co...
# 9    The people that don't interest about the effec...
# Name: sentence, dtype: object
# ../sentences-to-annotate/139094.xlsx
# 0                I completely agree with the statement.
# 1     We are in the consumis time, that means that p...
# 2     In this way a person always feels to be origin...
# 3     With this new conception of the money and abou...
# 4     In this way people feel obliged to buy the las...
# 5     And what is the best way to let their new prod...
# 6     The answer for this question is simple and eve...
# 7                  Simply the answer is: advertisement.
# 8     We can watch the tv or only look at every jour...
# 9     If the advertisement is the quicker and most s...
# 10    And in order to sell more pieces of a product,...
# 11    It's not a true lie, but only a manner to pubb...
# 12    For this reasons advertisements make product b...
# Name: sentence, dtype: object
# ../sentences-to-annotate/258897.xlsx
# 0     In later years advertisenments have increased ...
# 1     The most part of spots presents product or ser...
# 2     Many and many tecniques are used to present pr...
# 3     Using this tecnique icecreams will appear to b...
# 4     I completely refuse the trend to present produ...
# 5     In my opinion advertisements must present prod...
# 6     Presenting products in such a way is also a ri...
# 7     Probably they will not buy something from that...
# 8     I think that also governement should do someth...
# 9     If a product seems better that it really is, S...
# 10    Nowadays firms must create advertisements that...
# 11    Firms could stop this trend by creating a team...
# 12    Before publishing advertisements the control t...
# 13    If the check is positive, the advertisement ca...
# 14    This is also a way to help customers to choose...
# Name: sentence, dtype: object
# ../sentences-to-annotate/63040.xlsx
# 0     I agree with the statement "Most advertisement...
# 1     I think today the companies are spending a lot...
# 2     In fact, I think that, if the people would thi...
# 3     I am very interesting in this issue; and so, i...
# 4     I know that this is today quite difficult to a...
# 5     Another reason, I want to argue to support my ...
# 6     I think it is due to the quality of food we ar...
# 7     In fact; today the people have and average of ...
# 8     I thing also the governement should take some ...
# 9     The last reason, I would like to point out, is...
# 10    I know that today this field is not so importa...
# 11    I hope the huge companies will not conquest th...
# 12    I know that the progress can not be avoided, b...
# 13    I hope we could give to our sons a world bette...
# Name: sentence, dtype: object
# ../sentences-to-annotate/95457.xlsx
# 0                Today, advertisements are everywhere.
# 1    We are bombed by them in almost every part of ...
# 2    They are so spread that we often difficulty no...
# 3    So, to catch our attention, today advertisemen...
# 4    Infact a society must to send us a message tha...
# 5    There is no need to mention that it's not true...
# 6    Therefore what we need in reality is just a re...
# 7    Thus, if a society must convince us in every w...
# 8    A customer needs  not to trust advertisement a...
# 9    And we should alway wonder if we really need a...
# Name: sentence, dtype: object
# ../sentences-to-annotate/338634.xlsx
# 0    I am agree with the statement " Most advertise...
# 1    Actually most advertisements can help people t...
# 2    This can help people not also for the really m...
# 3    For this reason the advertisements make produc...
# Name: sentence, dtype: object
# ../sentences-to-annotate/1887730.xlsx
# 0                           Advertisments are enticing.
# 1     They are put out into the market to influence ...
# 2     In todays world more time is being spent in fr...
# 3     The argument on whether 'Most advertisment mak...
# 4     Commercials that are made for the general publ...
# 5     In this short span of time the concept of the ...
# 6     For example the Mastercard commercial that sho...
# 7     Well, here it show how this card can make you ...
# 8     This product, a plastic card can change a pers...
# 9                           Your credit should be good.
# 10    Most of the times, commercails for cosmetics u...
# 11    This product looks perfect  on them, they seem...
# 12    Well guess what, they are doing it because the...
# 13    Here the idea is to have a celebrity endorse t...
# 14    For example, Avon, Salma Hayak is the spokespe...
# 15    She looks amazing in the lipstick, her eyes da...
# 16    You too can copy that look,but not look exactl...
# 17    The product will do the same for you, the only...
# 18    Televison,radio, billboards, print are ways of...
# 19    This is way that the general public gets infor...
# 20    Advertisment is about creativity and showing w...
# Name: sentence, dtype: object
# ../sentences-to-annotate/214747.xlsx
# 0     Advertising consists of convincing potential c...
# 1     In some cases the advertised features of the p...
# 2     For example, it is relatively easy to verify w...
# 3     In this case advertising can make the commodit...
# 4     However, to my knowledge, these forms of adver...
# 5     In many - perhaps most - other cases, the qual...
# 6     For example, a company could advertise a drink...
# 7     In itself, this statement means nothing and ca...
# 8     However, if the advertising campaign is well d...
# 9     In such cases, advertising changes the product...
# 10    That is, a given item without advertising is i...
# 11    Therefore I would not agree with the statement...
# Name: sentence, dtype: object
# ../sentences-to-annotate/10345.xlsx
# 0     In an age of mass production and consumption, ...
# 1     The consumer wants to know that he is getting ...
# 2     It is then no surprise that when companies adv...
# 3     Advertisements of beauty products are a good e...
# 4     The consumer wants a mascara that will lenghte...
# 5     All cosmetic companies know this and, year aft...
# 6     Dramatic pictures shown on television or print...
# 7     If the companies mentioned these side-effects,...
# 8     This scheme seems to be working, since the new...
# 9     Diet pills are also advertised as being much m...
# 10    The typical advertisement shows pictures of (p...
# 11    Of course, the "after" pictures are always tak...
# 12    They are also digitally enhanced, to the point...
# 13    In any case, the pictured consumers appear thi...
# 14    But do diet pills really bring about such form...
# 15    Advertisers conveniently omit the need to bala...
# 16    Just the same, the makers of these diet pills ...
# 17    Finally, even if these diet pills are effectiv...
# 18    After all this person has not changed his or h...
# 19    In conclusion, manufacturers must resort to so...
# 20    However, I don't believe this is done specific...
# 21    It remains the consumer's duty to understand t...
# Name: sentence, dtype: object
# ../sentences-to-annotate/421490.xlsx
# 0    I surely agree with the opinion that  most adv...
# 1    In my opinion a very great number of these adv...
# 2    This fact could be expleined thinking that the...
# 3    Instead the television is used by a number of ...
# 4    Indeed it' s easy for youngs to believe in a w...
# 5    Advertisements that gives am image of a produc...
# 6    To conclude I think it's a very serious proble...
# Name: sentence, dtype: object
# ../sentences-to-annotate/1304821.xlsx
# 0     Advertisements are one of the most power means...
# 1     Undoubtedly, nowadays, advertisements are ever...
# 2     There are on the TV, in the radio, on the top ...
# 3     Most of advertisements combine with words and ...
# 4     I Take myself as an example, I was always bein...
# 5     Nevertheless, have you ever think about that a...
# 6     Are these modles on the billbroad really as pe...
# 7     I mean They have no pimples or extra hairs at ...
# 8     Something must be done for this advertisement ...
# 9     After I went to graphic design school to obtai...
# 10    In this way,  advertisements will attract coms...
# 11        However, it brought about many disadvantages.
# 12    Some products in the advertisements look too g...
# 13    For instance, one day, I went to lunch at Wend...
# 14               Then I bought it without a hesitation.
# 15    When I recieved the food from the attentant, I...
# 16    The food is not good enough than I expected be...
# 17    From that day, I didn't trust food advertiseme...
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# 30                                                  NaN
# 31                                                  NaN
# 32                                                  NaN
# 33                                                  NaN
# 34                                                  NaN
# 35                                                  NaN
# 36                                                  NaN
# 37                                                  NaN
# 38                                                  NaN
# 39                                                  NaN
# 40                                                  NaN
# 41                                                  NaN
# 42                                                  NaN
# 43                                                  NaN
# 44                                                  NaN
# 45                                                  NaN
# 46                                                  NaN
# 47                                                  NaN
# Name: sentence, dtype: object
# ../sentences-to-annotate/215896.xlsx
# 0    I can say I do agree with the statement becaus...
# 1    The characteristics described in TV advertisin...
# 2    Fact is, that people can effectively realize h...
# 3    Now, what are the strategies people can develo...
# 4    First, they can try to get suggestions from pe...
# 5    Second, they can take advantage of the large n...
# 6    Third, people can always count on some associa...
# 7    These are often no profit organization which a...
# 8    In conclusion I would like to recommend people...
# Name: sentence, dtype: object
# ../sentences-to-annotate/29229.xlsx
# 0                           I agree with the statement.
# 1     Economic rules changed a lot during the last s...
# 2     The arrive of television and the expansion of ...
# 3     This brougth to a challenge to convince consum...
# 4     To do this, advertisements try to make product...
# 5     A typical example that comes in my mind referr...
# 6     All over the world we can see advertisements s...
# 7     In the Formula1 championship, that is a race c...
# 8     In the 2005 Indianapolis Formula 1 Grand Prix,...
# 9     During the racing weekend, a lot of Michelin t...
# 10    Because of this problem, no cars using Micheli...
# 11      Only cars using Bridgestone tyres were allowed.
# 12    That was a perfect example that Michelin is no...
# 13    Michelin, after the problems created, had to r...
# Name: sentence, dtype: object
# ../sentences-to-annotate/791390.xlsx
# 0    in our society we live arounded by every kind ...
# 1    spots are became very important for all indust...
# 2    for this reason who make spot want to realize ...
# 3    but we do not often pay attention to them and ...
# 4    in this way the spots can easily influence who...
# 5    this aspect can be dangerous for children who ...
# 6    so i think that autorithies must controll much...
# Name: sentence, dtype: object
# ../sentences-to-annotate/341648.xlsx
# 0    This statment illustrate the advertising polic...
# 1    First, in our society of "mass consommation", ...
# 2    Thus it is always a relevent manner to make se...
# 3    For example, MC Donnald always showes on adeve...
# 4    Secondly, the successfull of a product is to a...
# 5    Whatesoever is the product, its advertissement...
# 6    Beasides, if the advertissement on the product...
# 7    Futhermore profit's policy that governs compan...
# 8    Finally this behaviour has for result to creat...
# 9    Thus creating a legal frame work on advertisse...
# Name: sentence, dtype: object
# ../sentences-to-annotate/986162.xlsx
# 0    I agree that most advertisements make products...
# 1    Useing a below average materials in some produ...
# 2    For example, a hire dryer that will be bought ...
# 3         The seacond reason is consumer satisfaction.
# 4    Seeing an advertisment about a very comfortabl...
# 5      In conclusion, not all advertisements are true.
# 6    It's all about selling there products in other...
# 7               Consumers are the last in there tasks.
# Name: sentence, dtype: object
# ../sentences-to-annotate/1431699.xlsx
# 0     I agree that advertisements make products seem...
# 1     I base my opinion on substantial points favori...
# 2     One of the important things observed in advert...
# 3             Let us take an example of  " X hair dye".
# 4     The advertisement for this says that " You can...
# 5     Some person develops an allergy with the hair ...
# 6     It was not the problem with the person but the...
# 7     The consumer is entailed to read and verify al...
# 8     Most of the cases, we as consumers, come to kn...
# 9     I believe that giving incomplete information i...
# 10    Various products are available in the market a...
# 11    Advertisements play a significant role of mani...
# 12    Let us take an example of an auto insurance ad...
# 13    Geico in the north eastern part of United Stat...
# 14    Any consumer gets easily lured to Geico's webs...
# 15    On careful analysis it is observed that some o...
# 16    Geico provides low insurance rates to consumer...
# 17    This factor is common for all auto insurance c...
# 18    If only, Geico would have advertised "We sell ...
# 19    Thus advertisements manipulate the fact and do...
# 20    Under most of the circumstances, cost is major...
# 21    Advertisements do a fantastic job in not revea...
# 22    For example, a consumer gets lured to buy  a w...
# 23    He has almost narrowed down his search and sta...
# 24        Cost has been a major factor in his decision.
# 25    Once he starts talking to the sales representa...
# 26    These other components increase the cost of th...
# 27    If the advertisers would have portrayed the ne...
# 28    To conclude, I believe that advertisers do an ...
# 29    Most of the time the advertisers do ensure tha...
# 30    But in all these cases, a decent amount of tim...
# Name: sentence, dtype: object
# ../sentences-to-annotate/42760.xlsx
# 0                   I totally agree with this sentence.
# 1     Attracting a new client is the base of adverti...
# 2     I graduated in Marketing two years ago and the...
# 3     This statement, that might sound quite absurd ...
# 4     The main reason to support this concept is tha...
# 5     Many researches based on customers purchases h...
# 6     This example clarifies how it's not important ...
# 7     The producer must focus his attention on  what...
# 8     If a person in charge of a marketing departmen...
# 9     Moreover, as the range of possible items is co...
# 10    If a product shows many possible upsides from ...
# 11    The more you exagerate in showing an item, the...
# 12    Of course, this doesn't always works becouse y...
# 13    To sum up, I would say that advertising is an ...
# 14                          Something you cannot learn.
# 15    Something innate through which you lead people...
# Name: sentence, dtype: object
# ../sentences-to-annotate/452402.xlsx
# 0     I agree with this sentence, especially after t...
# 1     In fact, at the beginning there were shops and...
# 2     The focus was on the relationship between the ...
# 3     The rule of owners as vendors was critical for...
# 4     Then arrives supermarkets and stores with publ...
# 5     Publicity made with flyers and big images in t...
# 6     Nowadays the increasing of technologies, such ...
# 7     It's not important what you said or who's your...
# 8     A spot on TV, created as a "short story" or a ...
# 9     Also using a famous testimonial for your spot,...
# 10    The globalization made by Internet allowed a p...
# 11    In conclusion, well-done advertisements not on...
# Name: sentence, dtype: object
# ../sentences-to-annotate/1020881.xlsx
# 0        I agree with this statement for these reasons.
# 1                                                   NaN
# 2     First, most advertisements appeal an advantage...
# 3     Let's think about the advertisements of a medi...
# 4     Most of them highlighted the effcet of the pro...
# 5     not even suggestiong the side-effect of the pr...
# 6     In particular, the medicines for a diet, which...
# 7     If the advertisement of these products do not ...
# 8                                                   NaN
# 9     Secondly, advertisement tend to attract a cust...
# 10    The real product seem not to be different from...
# 11    This is one of the strategies of advertisment ...
# 12    In addition, studiest indicated that these lit...
# 13                                                  NaN
# 14    Third, people are likely to listen to someone ...
# 15    Because of this fact, some advertisment appeal...
# 16    This makes people entirely rely on the statesm...
# 17                                                  NaN
# 18    Advertisement is useful sometimes because it p...
# 19    But it could fool customers in order to make p...
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# Name: sentence, dtype: object
# ../sentences-to-annotate/959192.xlsx
# 0     we are in the XXI century and now I must write...
# 1     I agree whit this idea because often many prod...
# 2     In fact I thinck that the television introduce...
# 3     For example some people buy only shoes or the ...
# 4     Many people do not know what is the true, beca...
# 5     We can value these products for the material t...
# 6     The apparence is most important but I thinck t...
# 7     This idea is rediculeus because the apparence ...
# 8     For example, I am an architect, when I make a ...
# 9     It must be the hause of live not only a beauti...
# 10    By the way many people do not understand that ...
# Name: sentence, dtype: object
# ../sentences-to-annotate/95939.xlsx
# 0    the advertisements tell how good are the thing...
# 1    another way to make you an advertisement is to...
# 2    in other way  another advertisement is to stud...
# 3    advertisement is a way to tell what cut happen...
# 4    eventhou they dont give the time to do it you ...
# Name: sentence, dtype: object
# ../sentences-to-annotate/774820.xlsx
# 0    I completely agree with this statement.In my o...
# 1    Advertisements make the products look much mor...
# 2    However,a lot of the times it is very unfair t...
# 3    There is not much anybody can do about this ei...
# 4    I think most of the advertisements are very mi...
# Name: sentence, dtype: object
# ../sentences-to-annotate/401099.xlsx
# 0     The goal of advertisement is to attract people...
# 1     I agree with that, and I will explain with som...
# 2     Most commercials are these days shown on tv, t...
# 3     Specified products are sponsorized between cer...
# 4     At night, depending on the movie playing, the ...
# 5     If it's a romantic movie, we are most likely t...
# 6     Some products, such as lingerie, tend to show ...
# 7     Women will be incentivated to buy it because t...
# 8     Sex is, in fact, part of our instinct, and tha...
# 9     Another area where we are more sensible is foo...
# 10    This way, it's very important to advertise a f...
# 11    Since we have been bombarded of images of perf...
# 12    But the new target of advertisement are the ch...
# 13    Anyway, I think that a more specified type of ...
# 14    We are always looking for the latest status sy...
# 15    The only thing that I suggest is to reduce the...
# Name: sentence, dtype: object
# ../sentences-to-annotate/254471.xlsx
# 0    To my mind, most advertisements make products ...
# 1    First, there are a lot of advertisements which...
# 2    For exemple, for products to wach white tee sh...
# 3    Then, we discover there are a lot of liing adv...
# 4    When we buy a product to wash bath room, they ...
# 5    finaly, we find a lot of advertisements for on...
# 6    He is always new, but there are the same ingre...
# 7    If we mustn't be radical on this subject, we c...
# Name: sentence, dtype: object
# ../sentences-to-annotate/636989.xlsx
# 0    IN NOWADAYS,PEOPLE BUY THE PRODUCTS BY ONLY LO...
# 1    FIRSTLY,IN THOSE DAYS PEOPLE MOSTLY BUY TEH PR...
# 2    THUS,YOU JUST SEE THE ADVERTISEMENT SO YOU CAN...
# 3    ON THE OTHER HAND,I WOULD LIKE TO GIVE AN EXAM...
# 4    I THINK WHEN PEOPLE WANT TO BUY SOMETHING,THEY...
# Name: sentence, dtype: object
# ../sentences-to-annotate/1569422.xlsx
# 0     Advertising is one of the key factors in the s...
# 1     Some people feel that most advertisements make...
# 2     I do not agree with this and will explain my p...
# 3     In today's world, there is a lot of awareness ...
# 4     They know that if they give a false picture of...
# 5     Therefore, intelligent and successful business...
# 6     Thus, we generally do not see an add of a prod...
# 7     In today's world, only the best products are a...
# 8     It is generally these successful companies who...
# 9     As the market is very competitive, there is li...
# 10    The motive of advertising of such companies is...
# 11    Therefore, I do not think that companies that ...
# 12    Neither do they have the money nor is it worth...
# 13    If we observe the advertisements nowadays, we ...
# 14    Companies sometimes do blow up their product i...
# 15    They do not project wrong information about th...
# 16    Therefore, I feel that advertisements project ...
# Name: sentence, dtype: object
# ../sentences-to-annotate/164339.xlsx
# 0     A good advertisements has to make products see...
# 1     Every day, we whatch on the television or see ...
# 2     They offer to us a perfect body or a cleaned k...
# 3     It's important that a successful advertise wou...
# 4     It's true that in the world there's a lot of p...
# 5     The useful of the advertisement, wherever they...
# 6     I think that a person in order to sale somethi...
# 7     I hate the numerous sales advertisements that ...
# 8                      They only want cheat the people!
# 9     In Italy, we have a TV program which looks for...
# 10    Very often, the people who are cheated are poo...
# 11    On this money there's a too big and uncorrect ...
# 12    But this is one of the awful cheating that scr...
# 13    Another one could be about astrologists who as...
# 14    But I think that the world could not change as...
# Name: sentence, dtype: object
# ../sentences-to-annotate/387499.xlsx
# 0                 I strongly agree with the statement.
# 1    Most advertisements make products better than ...
# 2    First, advertisements enphatize the quality of...
# 3    Sometimes advertisements give true but incompl...
# 4    They assured free assistance calling a free nu...
# 5    Second, they usually do not talk about disadva...
# 6    In addition, advertisements often do not give ...
# 7    That is very important in particular if items ...
# 8    For example It happenened that, after the II w...
# 9    Cocluding, I do not saying advertisements shou...
# Name: sentence, dtype: object
# ../sentences-to-annotate/449429.xlsx
# 0    Now adays advertisement is the best way to sel...
# 1    First,Advertisement only shows the good qualit...
# 2    Second,Advertisement make product look In bett...
# 3    Finally,Advertisement shows that products are ...
# 4    In conclusion ,I like to say that most of the ...
# Name: sentence, dtype: object
# ../sentences-to-annotate/1159224.xlsx
# 0     In todays world of cut throat competition, adv...
# 1     There is a large variety of products available...
# 2     Similar products are manufactured by many comp...
# 3        Hence customer today has a variety of chooice.
# 4                                                   NaN
# 5     The differences in these similar products may ...
# 6     The advertising helps in exaggerating this dif...
# 7                                Take cars for example.
# 8     One car manufacturer may exaggerate about the ...
# 9     Another car manufacurer in the same category m...
# 10    Thus both the manufacturers have a selling poi...
# 11                                                  NaN
# 12    But as the saying goes looks can be decieving ...
# 13    There are so many instances in which the custo...
# 14    These instances are coming to life almost ever...
# 15    There  are many letters in the 'letter to the ...
# 16    Let us consider a simple example of buying an ...
# 17    One of my close friends wanted to buy a new ap...
# 18    He decided to finalize on the basis of the bro...
# 19    The brochure of the apartment he zeroed on spo...
# 20    After actually shifting to the apartment he wa...
# 21    But if the advertisement hoardings were to be ...
# 22    This is a common case for a large variety of p...
# 23                                                  NaN
# 24    Going from the advertising point of view, the ...
# 25    Take an example of a popular razor which shows...
# 26    This razor actually caused skin problems to a ...
# 27    But the company that made this ad made profit ...
# 28                                                  NaN
# 29    There are many more instances which help in su...
# 30                                                  NaN
# 31                                                  NaN
# 32                                                  NaN
# 33                                                  NaN
# 34                                                  NaN
# 35                                                  NaN
# 36                                                  NaN
# 37                                                  NaN
# 38                                                  NaN
# 39                                                  NaN
# 40                                                  NaN
# 41                                                  NaN
# 42                                                  NaN
# 43                                                  NaN
# 44                                                  NaN
# 45                                                  NaN
# 46                                                  NaN
# 47                                                  NaN
# 48                                                  NaN
# 49                                                  NaN
# 50                                                  NaN
# 51                                                  NaN
# 52                                                  NaN
# Name: sentence, dtype: object
# ../sentences-to-annotate/1647196.xlsx
# 0    Most advertisments makes product much better w...
# 1    When you deside to buy it hten you fids that i...
# 2    The product which is mostly shown in commercia...
# 3    I have purchased several items from the advert...
# 4    I thing the best way to buy any thing you shou...
# 5    I thing that is the only best way to buy any t...
# 6    So i sugest that to buy mostly only by going t...
# Name: sentence, dtype: object
# ../sentences-to-annotate/80920.xlsx
# 0     I am agree with the statemant that most advert...
# 1        To support my opinion I have a series reasons.
# 2     I think that the presentation of a product is ...
# 3     You imagine a person that go to buy a product ...
# 4     Of course a person will chose the product with...
# 5     This is an example to demostrate how our idea ...
# 6     I think that television is the most important ...
# 7     It is incredible how television influences the...
# 8     I have many friends that stated that they purc...
# 9     They think that if a product is merchandised a...
# 10    This is true in some case but it is completely...
# 11    I think that it is necessary to valuate a prod...
# 12    However people have not time and in some case ...
# 13    So they buy the product that usually view at t...
# 14    Enterprises do their interersts and out of dub...
# 15    So enterprises do their game but customers wou...
# Name: sentence, dtype: object
# ../sentences-to-annotate/1165367.xlsx
# 0     I agree with the statement that most advertise...
# 1                                                   NaN
# 2     Due to advancements in technological and finan...
# 3     Because of the excess liquidity in the current...
# 4     There are a number of companies that are produ...
# 5     They themselves know that it is extremely diff...
# 6     But they all have realised one way of selling ...
# 7                                      Advertisements!!
# 8     Now technically they know that they can't diff...
# 9         Let's take an example of a car advertisement.
# 10              It's an entry level car Hyundai Santro.
# 11    They have  Mr. Shahrukh Khan (Popular Filmstar...
# 12    In their advertisement it's shown that Mr. Sha...
# 13    Now everyone in the world knows that Mr. Shahr...
# 14    But people are fascinated by this and buy cars...
# 15    Having one myself, i know it is a good car but...
# 16    They show that if you use this car then you ma...
# 17                                                  NaN
# 18    I think it is appropriate to discuss example o...
# 19                  It is a drink for growing children.
# 20    They claim in advertisements that if children ...
# 21    Now if that was the case then producer should ...
# 22    I agree with their claims regarding content of...
# 23                                                  NaN
# 24    Let's take another example for a telecom servi...
# 25    In it's advertisement they claim that they pro...
# 26        I fell into the trap and took the connection.
# 27    For the first time when I went to the outlet f...
# 28    Eventually after having a verbal argument I to...
# 29                                                  NaN
# 30    I belive that to survive in this cut throat wo...
# 31                       Advertisements is one of them.
# 32    Whatever you see on TV, you should not believe...
# 33                                                  NaN
# 34                                                  NaN
# 35                                                  NaN
# 36                                                  NaN
# 37                                                  NaN
# 38                                                  NaN
# 39                                                  NaN
# 40                                                  NaN
# 41                                                  NaN
# 42                                                  NaN
# 43                                                  NaN
# 44                                                  NaN
# 45                                                  NaN
# 46                                                  NaN
# 47                                                  NaN
# 48                                                  NaN
# 49                                                  NaN
# 50                                                  NaN
# Name: sentence, dtype: object
# ../sentences-to-annotate/42310.xlsx
# 0     I strongly agree with the statement that most ...
# 1     But this is my opinion, I think the common opi...
# 2       First I want to provide my personal experience.
# 3     Two weeks ago I bought a personal computer of ...
# 4     The advertising was amazing, the quality of th...
# 5     In reality it's just the evolution of a normal...
# 6     This is just an exemple of a personal experien...
# 7     I have the chance to have a friend working in ...
# 8     Her opinion is not in costrast with mine but s...
# 9     Her point is that the some customer needs to b...
# 10    At the end he believes that the responsible fo...
# 11    As conclusion I want to say that most advertis...
# Name: sentence, dtype: object
# ../sentences-to-annotate/1013285.xlsx
# 0     I todays world with advancement in technology ...
# 1     These advertisements are best way of marketing...
# 2     But the question arises, Are these advertiseme...
# 3                  what they advertise well not always.
# 4     The advertising industry is continuously growi...
# 5     The advertisement developers make it so attrsa...
# 6     Even some people love to watch advertisements ...
# 7     In the recent past we have seen so many cases ...
# 8     For example there was a case on a skin lotion ...
# 9     The advertisement of that company claimed that...
# 10    Whereas it never happened and subsequently the...
# 11    Such advertisements are nothing but tools of f...
# 12    The government agencies should certainly make ...
# 13    Summarily i would say that most of the adverti...
# Name: sentence, dtype: object
# ../sentences-to-annotate/146183.xlsx
# 0    Advertisements play really an important role i...
# 1    The world of industry is affected mostly by th...
# 2    This is the role of advertisement: to make a p...
# 3    Therefore, aiming at creating the customer's i...
# 4    In most cases advertisement describes the prod...
# 5    Althought this behavior is quite commonly acce...
# 6    Actually the advertisement, that is so importa...
# 7    Many associations protecting the rights of the...
# 8    This causes many questions on whether it is de...
# 9    In Italy we have a kind of regulation that dem...
# Name: sentence, dtype: object
# ../sentences-to-annotate/377584.xlsx
# 0     Advertisements have become an important part o...
# 1     We rely so much on the advertisements and brin...
# 2     But, most of the advertisements make the produ...
# 3                              I totally agree to this.
# 4     I have heard lots from people about the superf...
# 5     There are lot of hair related products like sh...
# 6     I have dry and weak hair .I happened  to see a...
# 7     There advertisement poised a model having silk...
# 8     So relying on the advertisement i bought that ...
# 9     Basically they try to sell their products by m...
# 10     Lets consider the example of fitness intruments.
# 11    The advisements shows that if you will use thi...
# 12    Since in US obesity is the major problem, so p...
# 13    They do loose some of pounds but it not the sa...
# 14    In most of the adverstisements, they will just...
# 15    I want to tell one of my friends experience ab...
# 16    She took one cellphone service watching its ad...
# 17    But she is repenting her decision of using tha...
# 18    In my opinion, not all but most advertisements...
# 19    So, in my view we should not blindly rely on t...
# Name: sentence, dtype: object
# ../sentences-to-annotate/623728.xlsx
# 0     I believe that most of the products we see on ...
# 1     Two years ago I bought a face cream I had seen...
# 2     This kind of misrepresentations are really com...
# 3     The companies represent their products better ...
# 4     These companies have great competition between...
# 5     Their way to sell more product is to show thei...
# 6     Besides the companies, the advertisement agenc...
# 7     Since they are in the business to make people ...
# 8     While they are doing this untrue presentation,...
# 9     from this arrengement \nIn a conclusion, today...
# 10    I took my lesson two years ago and I hope ever...
# 11    This misrepresentation will continue as long a...
# Name: sentence, dtype: object
# ../sentences-to-annotate/125439.xlsx
# 0     The advertisement world sometimes is bigger th...
# 1     I have to agree with the statement because the...
# 2     Fisrt everything comes first right in to the h...
# 3     As examples we have Coca Cola and Pepsi, is ob...
# 4     And here is easy to read a great advertisment ...
# 5     Is has been seen in the aspects of beauty,adve...
# 6     And evidentiially all kind of people wanting t...
# 7     Third because the people are been bombarded co...
# 8     So now the companys have to figure out how to ...
# 9     But what became a tool, now created a silent w...
# 10    The best advertising wins; but this leaves som...
# 11    As an example I bought a drink nad it looked g...
# 12    So in conclution even a fantastci advertisment...
# Name: sentence, dtype: object
# ../sentences-to-annotate/414977.xlsx
# 0     In the twentieth century advertising has becom...
# 1     Most of the advertisements, though, try to exa...
# 2     Even if of course I can't appreciate this beha...
# 3     This would stress also the workers, as they wo...
# 4     The problem is that the global system is now b...
# 5     But these behaviour is well established and so...
# 6     There is nothing we can do besides using our f...
# 7     There is a moment when this behaviour by compa...
# 8     If a company sells a product that is toxic, un...
# 9     For example, I know that sometimes the water t...
# 10    But the laboratory tests have been made in the...
# 11    This is an example of a lie told by the State ...
# 12                               What can a citizen do?
# 13    I drink water in bottles, even if I'm not sure...
# 14    We can't be sure about anything regarding what...
# Name: sentence, dtype: object
# ../sentences-to-annotate/985545.xlsx
# 0     The companys in the world build a lot of produ...
# 1     So the companys spend a lot of money in TV spo...
# ...
# 4                                                   NaN
# 5     Take an example of a cosmetic company in all t...
# 6     Why all thanks to the product of the company t...
# 7     We people get carried away so much by these be...
# 8                                                   NaN
# 9     None of these advertisements anywhere will sho...
# 10    Also none of these advertisment will take any ...
# 11    Like meeting your prince charming on a subway ...
# 12    The only thing I can smell is other persons ba...
# 13                                                  NaN
# 14    Most of the times as a parent it is vey diffic...
# 15    Also why most of the food chains make their pr...
# 16                                                  NaN
# 17    In my opinion companies should take responsibi...
# 18    They should instead of spending thousands on p...
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# 30                                                  NaN
# 31                                                  NaN
# 32                                                  NaN
# 33                                                  NaN
# 34                                                  NaN
# 35                                                  NaN
# 36                                                  NaN
# 37                                                  NaN
# 38                                                  NaN
# 39                                                  NaN
# 40                                                  NaN
# 41                                                  NaN
# 42                                                  NaN
# 43                                                  NaN
# Name: sentence, dtype: object
# ../sentences-to-annotate/1356555.xlsx
# 0     I am agree with the statement that advertiseme...
# 1     If a particular product is launched then genar...
# 2     Below I will explain for what kind of product ...
# 3     In competing market generally the company says...
# 4           The company tries to sell it's poduct more.
# 5     So in it's information they genrally put false...
# 6     You can see this kind of trend more in cosmeti...
# 7     Every hair shampoo is more or less same.They a...
# 8     They says that thier shampoo is more effective...
# 9     Sometimes it also happen that company make che...
# 10    To do this they make false advertisemnt about ...
# 11    You can see this when a roaming salesperson co...
# 12    It also happen that sometimes an advertisement...
# 13    For an example, say someone wants to sell slip...
# 14    The advertisement says that the sleeping pill ...
# 15    The advertisement is not going to tell you abo...
# 16    But you can't say all of the advertisements gi...
# 17    Some of the advertisement really give helpful ...
# 18    We should analyze an advertisement only on it'...
# Name: sentence, dtype: object
# ../sentences-to-annotate/89860.xlsx
# 0                I completely agree with the statement.
# 1            Nowaday advertising  show you a lifestyle.
# 2     They mainly speaks about the feeling or how yo...
# 3     That because this is the most important way to...
# 4     Playing with the feelings :a psycological appr...
# 5     The more advertisement are made the more a pro...
# 6     Advertisements are less involved in the qualit...
# 7     To show the potentials of a good is less actra...
# 8     If a product will became a trend a big amount ...
# 9     On television the advertisement are like a sho...
# 10           The "slogan" or "jingle" is important too.
# 11                              It is part of our life.
# 12                        It must be a funny statement.
# 13                      Poeple must remember it easily.
# 14    But sometimes it's not related with the qualit...
# 15    I my opinion showing a product at the supermar...
# 16          I particulary agree with "test promotions".
# 17    For example, going at the supermarket and test...
# 18    In this way investiment in advertisement are m...
# 19    Sometime it depends on the kind of products we...
# Name: sentence, dtype: object
# ../sentences-to-annotate/666721.xlsx
# 0    Recant advertisements world's   consists of ma...
# 1    Marketing polisies'  requarements  are based o...
# 2                            So how can saler do that?
# 3    As a way they must promote their product even ...
# 4    And people even they are really not sure about...
# 5    Unfourtunatly , human nature  focused on consu...
# Name: sentence, dtype: object
# ../sentences-to-annotate/1013583.xlsx
# 0     I agree with with the statement that most adve...
# 1        I hold this opinion for the following reasons.
# 2                                                   NaN
# 3     If we think about cataloges around the fashoni...
# 4     We have no Clue that this is not going to happen.
# 5     The pictures we see in the cataloges promises ...
# 6                                                   NaN
# 7     Another example I like to use are advertisemen...
# 8     This can be a very disappointing experience fo...
# 9                                                   NaN
# 10    One example of a failing result is sometimes e...
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# Name: sentence, dtype: object
# ../sentences-to-annotate/140614.xlsx
# 0       I agree with this statement without any doubts.
# 1     It is sure that without any advertisement a pr...
# 2     But it is always necessary to consider the lim...
# 3     Or better, I think that people working to make...
# 4         And the problem is that they profite of this.
# 5                               Here are some examples.
# 6     If you are a child why not to have the best vi...
# 7     And if you are a teenager, a girl looking for ...
# 8     Then, if you are fatty, why not to buy the low...
# 9     And when you are getting older.... woul not yo...
# 10    It is quite sad, on my opinion, that we could ...
# 11    Now my question is: could my life be so differ...
# 12                                I can be sure of not.
# 13    But the paradox is that me too I constantly fa...
# 14    So to be careful of what is presented to us is...
# 15                               Then to look for essen
# Name: sentence, dtype: object
# ../sentences-to-annotate/1135415.xlsx
# 0     The influnce of advertisements on the customer...
# 1     The advertisers are projecting thier goods to ...
# 2     I would like to agree with the statement that ...
# 3     As an example consider the advertisements of w...
# 4     The advertisements claim that it can remove di...
# 5     make the clothes shiny, maintains the colour o...
# 6          Most of these statements are projected ones.
# 7     Take another example of  washing soaps which h...
# 8     Some washing soaps claims that they can make p...
# 9     As long as  my knowledge is considered i never...
# 10    In the same manner as the case of washing powd...
# 11    The manufacturers of motor vehicles claim that...
# 12    In short the statement makes it clear that tha...
# 13    Hence it seems reasonable for me to agree with...
# Name: sentence, dtype: object
# ../sentences-to-annotate/1136669.xlsx
# 0                                                  Yes.
# 1     I do agree that most of the advertisements mak...
# 2     Advertisements infact in today's world do not ...
# 3     Instead they are supposed to be a glorified di...
# 4     In some cases  the promise may turn out to be ...
# 5     Advertisements are supposed to be in some case...
# 6     I say only because the products of that same f...
# 7     Its only upon the marketing and advertising fa...
# 8     And only when it makes a place in the customer...
# 9     In a world of competition, the manufacturer is...
# 10    And indeed as supported by the studies of the ...
# 11    Indeed if you add a bit of sheen to your produ...
# 12    And though they might buy it only after carefu...
# 13    Now the actual sales of a product would obviou...
# 14    So in my opinion the advertisement in todays w...
# 15                As real it can be kept, it should be.
# 16    But i would consider it compulsory to give a b...
# Name: sentence, dtype: object
# ../sentences-to-annotate/634817.xlsx
# 0     As a student majoring in bussiness management,...
# 1     However, this does not mean that advertisement...
# 2     For example, it is not allways possible to fin...
# 3     Thus is because the manufacturers tend to show...
# 4     First of all, it is common that most firms dec...
# 5     They try to show that their products serve ext...
# 6     A very good example of this is slimming produc...
# 7     I want to express something that happened to m...
# 8     In the television i saw the advertisement of a...
# 9     It was stated in the advertising that after a ...
# 10    Consequently, she would lose 5 kilos in two we...
# 11    As soon as i saw this advertisement, i bought ...
# 12    After two weeks, while dreaming of loosing fiv...
# 13    Secondly, in order to make customers buy their...
# 14    The most common example of this is the adverti...
# 15    Last year we wanted to go to a hotel for our s...
# 16    Thus, we searched the newspapers and among var...
# 17    The picture in the newspaper was so lovely tha...
# 18    But, after we went to the hotel it was a muddy...
# 19    Finally, in order to pursue the customers the ...
# Name: sentence, dtype: object
# ../sentences-to-annotate/1357667.xlsx
# 0               'Everything that glitter is not gold.'
# 1      summarizes my feeling on the subject very well.
# 2    This statement can not be more true in today's...
# 3    Advertising is an art of selling things or rat...
# 4    The best example of it is the weight loss prod...
# 5    At times you would realize after buying those ...
# 6    The other ones which particularly infuriates m...
# 7    The other are the products which make you look...
# 8       But then wouldn't the world be perfect hmm....
# Name: sentence, dtype: object
# ../sentences-to-annotate/1035126.xlsx
# 0     I think that most advertisements make products...
# 1     There are two reasons for my opinion: the pupo...
# 2                                                   NaN
# 3     First, the purpose of the advertisements makes...
# 4     The advertisement company should present the g...
# 5     When people see the advertisement, the goods s...
# 6     When I was a middle school students, I really ...
# 7     When I watched a fabulous advertisement of a c...
# 8     Finally, my parents accepted my seggestion and...
# 9     However, I found out my new computer used not ...
# 10    I pursuaded my parents with the computer becau...
# 11    I was very disappointed about the advertisemen...
# 12                                                  NaN
# 13    Second, the audiences does not see directly se...
# 14    People say that the goods on the picture or th...
# 15          My sister had a similar situation recently.
# 16    She bought a bag on the website which looked f...
# 17    However, she did not even recognize the bag be...
# 18    It was not the seller's fault but the camera's...
# 19    I read an article related to these happening; ...
# 20    Moreover, the advertisement companies devise t...
# 21    This problem means that people should not prec...
# 22                                                  NaN
# 23    Depends on my experiences and scientific knowl...
# 24    I hope that the advertisement companies try to...
# 25    Moreover, I wish that scientists invent more a...
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# 30                                                  NaN
# 31                                                  NaN
# 32                                                  NaN
# 33                                                  NaN
# 34                                                  NaN
# 35                                                  NaN
# 36                                                  NaN
# 37                                                  NaN
# 38                                                  NaN
# 39                                                  NaN
# 40                                                  NaN
# 41                                                  NaN
# 42                                                  NaN
# 43                                                  NaN
# Name: sentence, dtype: object
# ../sentences-to-annotate/1116877.xlsx
# 0    I believe most advertisement make products see...
# 1    This is because the kind of things shown in ad...
# 2    Firstly advertisement make products seem bette...
# 3    For example when an advertisement of a bike is...
# 4    With hyped mileage quoted in the advertisement...
# 5    Secondly companies intentionally make good adv...
# 6    By doing this they try to create a branding an...
# 7    Take for example laptop companies like Acer, H...
# 8    But in actuality it does it and is very simila...
# 9    Ultimately advertisements make products seem m...
# Name: sentence, dtype: object
# ../sentences-to-annotate/999352.xlsx
# 0    Most advertisements make products seem much be...
# 1    in fact, all over the world use this process.H...
# 2    first of all, i see wherever i go advertisemen...
# 3    Furthermore, the product owners have to compet...
# 4    In conclusion, the marketing for the product i...
# 5    Therefore, the products seem much better than ...
# Name: sentence, dtype: object
# ../sentences-to-annotate/1273125.xlsx
# 0     I agree with that most advertisements make pro...
# 1     There are two main reasons to couse this fact ...
# 2     One is the advertisment company have to\nprese...
# 3     The other one is high technology could make ev...
# 4                                                   NaN
# 5     The purpose of advertisments is making product...
# 6     For example,   \nto promote perfume, advertise...
# 7                                                   NaN
# 8     As today's technology, all of products can loo...
# 9     Using the computer graphic function can show t...
# 10                  Like car can ran fast than reality.
# 11           That's the reason i agree with that most a
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# Name: sentence, dtype: object

# %%
csv_file = 'output_final2.csv'
header = list(next(iter(word_difficulty.values())).keys())

# Write to CSV file
with open(csv_file, 'w', newline='') as file:
    writer = csv.DictWriter(file, fieldnames=['filename'] + header)
    
    # Write the header
    writer.writeheader()
    
    # Write data
    for filename, values in word_difficulty.items():
        row = {'filename': filename, **values}
        writer.writerow(row)

print(f"CSV file '{csv_file}' has been created.")
# Out:
# CSV file 'output_final2.csv' has been created.

# %%
def feature_engineering(filename):
    X, y = get_data(filename)
    corr = X.corr()
    ax = sns.heatmap(corr , vmin=0, vmax=1)
    plt.show()
